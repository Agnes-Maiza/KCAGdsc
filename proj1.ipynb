# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#creating data
x=np.arange(10, 50, 5)
print(x)
y=np.arange(5, 85, 10)
print(y)
# Out:
# [10 15 20 25 30 35 40 45]
# [ 5 15 25 35 45 55 65 75]

# %%
#plot
plt.close('all')
x=np.arange(10, 50, 5)
y=np.arange(5, 85, 10)
plt.plot(x,y)
plt.xlabel(r'$values of x$')
plt.ylabel(r'$values of y$')
plt.show()
