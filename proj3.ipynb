# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Series
x = np.arange(5,60,5)
print(x)
print("------------------------------------------------------------------")
y = pd.Series(x,index = ["a", "b", "c","d","e","f","g","h","i","j", "k"])
print(y)
# Out:
# [ 5 10 15 20 25 30 35 40 45 50 55]
# ------------------------------------------------------------------
# a     5
# b    10
# c    15
# d    20
# e    25
# f    30
# g    35
# h    40
# i    45
# j    50
# k    55
# dtype: int32

# %%
#Dataframes

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
print(data)
print("-------------------------------")
a = pd.DataFrame(data)
print(a)
# Out:
# {'calories': [420, 380, 390], 'duration': [50, 40, 45]}
# -------------------------------
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
plt.close('all')
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

plt.close('all')
plt.plot(a)
plt.title("Metabolzation")
plt.xlabel("Duration")
plt.ylabel("Calories")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
