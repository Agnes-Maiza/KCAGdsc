# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x= np.random.randint(10, size=10)
print(x)
y= np.random.rand(10)
print(y)
plt.close()

plt.bar(x,y)
plt.show()
plt.scatter(x,y)
plt.show()
# Out:
# [2 4 8 5 4 0 7 8 1 4]
# [0.19705013 0.03986242 0.41743691 0.3361591  0.69395155 0.24403195
#  0.05452465 0.45261782 0.49259936 0.74229948]
